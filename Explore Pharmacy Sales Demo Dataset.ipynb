# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ph = pd.read_csv('Demo Pharmacy Sales Data.csv')

# %%
df_ph
# Out:
#          Date Sold                                     Med_name  \
# 0       2021-05-07              Clotrimazole Topical Cream (2%)
# 1       2021-08-09   Alprostadil Urethral Suppository (125 mcg)
# 2       2021-06-15            Methyltestosterone Tablet (10 mg)
# 3       2021-02-19                      Buspirone Tablet (5 mg)
# 4       2022-09-24  Hydrocodone/Acetaminophen Tablet (5/325 mg)
# ...            ...                                          ...
# 999995  2020-11-29   Alprostadil Urethral Suppository (125 mcg)
# 999996  2021-03-30                   Fenoprofen Tablet (600 mg)
# 999997  2020-04-17                      Doxazosin Tablet (1 mg)
# 999998  2021-12-08             Flumazenil Injection (0.1 mg/mL)
# 999999  2022-08-16                   Prednisolone Tablet (5 mg)
#
#                                       Med_class  Quantity Sold  Price
# 0                                    Antifungal             66   86.9
# ...

# %%
df_ph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Date Sold      1000000 non-null  object
#  1   Med_name       1000000 non-null  object
#  2   Med_class      1000000 non-null  object
#  3   Quantity Sold  1000000 non-null  int64
#  4   Price          1000000 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 38.1+ MB

# %%
summary_stats = df_ph[['Quantity Sold','Price']].describe()
summary_stats
# Out:
#         Quantity Sold           Price
# count  1000000.000000  1000000.000000
# mean        50.524566       50.024411
# std         28.847235       28.872706
# min          1.000000        0.100000
# 25%         26.000000       25.000000
# 50%         51.000000       50.000000
# 75%         75.000000       75.100000
# max        100.000000      100.000000

# %%
df_ph['Quantity Sold'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Quantity Sold')
# Out:
# Text(0.5, 1.0, 'Histogram of Quantity Sold')

# %%
plt.subplot(1,2,1)
df_ph['Quantity Sold'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Quantity Sold') 

plt.subplot(1,2,2)
df_ph['Price'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Price Sold')

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
df_ph['Quantity Sold'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Quantity Sold') 

plt.subplot(1,2,2)
df_ph['Price'].plot.hist(bins=20,edgecolor='k')
plt.title('Histogram of Price Sold')

plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df_ph['Quantity Sold'],bins=20,kde=True)
plt.title('Histogram of Quantity Sold') 

plt.subplot(1,2,2)
sns.histplot(df_ph['Price'],bins=20,kde=True,color='purple')
plt.title('Histogram of Price Sold')

plt.show()
# Out:
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\anaconda\envs\tf\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Medication Class Analysis

# %%
df_ph.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Date Sold      1000000 non-null  object
#  1   Med_name       1000000 non-null  object
#  2   Med_class      1000000 non-null  object
#  3   Quantity Sold  1000000 non-null  int64
#  4   Price          1000000 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 38.1+ MB

# %%
df_ph['Med_name'].value_counts()
# Out:
# Med_name
# Tretinoin Topical Cream (0.025%)                     15027
# Ketoconazole Topical Cream (2%)                      11008
# Adapalene/Benzoyl Peroxide Topical Gel (0.1/2.5%)    10097
# Triamcinolone Topical Ointment (0.1%)                10083
# Clobetasol Topical Cream (0.05%)                      9984
#                                                      ...
# Guanfacine Tablet (2 mg)                               939
# Olopatadine Nasal Spray (665 mcg/spray)                938
# Methylphenidate Tablet (10 mg)                         938
# Lithium Carbonate Capsule (300 mg)                     920
# Clindamycin Topical Lotion (1%)                        917
# Name: count, Length: 279, dtype: int64

# %%
df_ph['Med_class'].value_counts()
# Out:
# Med_class
# Nonsteroidal Anti-Inflammatory Drug                        82146
# Phosphodiesterase Type 5 Inhibitor                         56294
# Alpha-Blocker                                              52208
# Anticonvulsant                                             49766
# Beta-Blocker                                               40673
#                                                            ...
# Norepinephrine Reuptake Inhibitor                            995
# Melatonin Receptor Agonist                                   983
# Cardiac Glycoside                                            981
# Anticholinergic/Short-Acting Beta-2 Agonist Combination      977
# Mood Stabilizer                                              920
# Name: count, Length: 87, dtype: int64

# %%
top_number = 20

# %%
top_classes = df_ph['Med_class'].value_counts().nlargest(top_number)
top_classes
# Out:
# Med_class
# Nonsteroidal Anti-Inflammatory Drug    82146
# Phosphodiesterase Type 5 Inhibitor     56294
# Alpha-Blocker                          52208
# Anticonvulsant                         49766
# Beta-Blocker                           40673
# Antifungal                             36163
# Corticosteroid                         35155
# Benzodiazepine                         33872
# Low-Potency Corticosteroid             29966
# High-Potency Corticosteroid            29923
# Opioid Analgesic                       29899
# Antibiotic                             24807
# Inhaled Corticosteroid                 22068
# 5-Alpha Reductase Inhibitor            21848
# Analgesic                              21108
# Prostaglandin E1 Analog                21031
# Retinoid                               20094
# Sympathomimetic                        19799
# Vasodilator                            19285
# Alpha-2 Agonist                        15865
# Name: count, dtype: int64

# %%
top_classes = df_ph['Med_class'].value_counts().nlargest(top_number).index
top_classes
# Out:
# Index([' Nonsteroidal Anti-Inflammatory Drug',
#        ' Phosphodiesterase Type 5 Inhibitor', ' Alpha-Blocker',
#        ' Anticonvulsant', ' Beta-Blocker', ' Antifungal', ' Corticosteroid',
#        ' Benzodiazepine', ' Low-Potency Corticosteroid',
#        ' High-Potency Corticosteroid', ' Opioid Analgesic', ' Antibiotic',
#        ' Inhaled Corticosteroid', ' 5-Alpha Reductase Inhibitor', ' Analgesic',
#        ' Prostaglandin E1 Analog', ' Retinoid', ' Sympathomimetic',
#        ' Vasodilator', ' Alpha-2 Agonist'],
#       dtype='object', name='Med_class')

# %%
## create a dataframe containing top 20 classes
df_top_med_classes = df_ph[df_ph['Med_class'].isin(top_classes)]
df_top_med_classes
# Out:
#          Date Sold                                    Med_name  \
# 0       2021-05-07             Clotrimazole Topical Cream (2%)
# 1       2021-08-09  Alprostadil Urethral Suppository (125 mcg)
# 6       2018-10-22          Norepinephrine Injection (2 mg/mL)
# 8       2022-05-19                    Rofecoxib Tablet (25 mg)
# 9       2019-07-21      Fluticasone Inhaler (50 mcg/actuation)
# ...            ...                                         ...
# 999992  2018-10-31               Carbamazepine Tablet (200 mg)
# 999995  2020-11-29  Alprostadil Urethral Suppository (125 mcg)
# 999996  2021-03-30                  Fenoprofen Tablet (600 mg)
# 999997  2020-04-17                     Doxazosin Tablet (1 mg)
# 999999  2022-08-16                  Prednisolone Tablet (5 mg)
#
#                                    Med_class  Quantity Sold  Price
# 0                                 Antifungal             66   86.9
# 1                    Prostaglandin E1 Analog             15   22.9
# ...

# %%
df_top_med_classes = df_top_med_classes.groupby('Med_class')['Quantity Sold'].sum().reset_index()

# %%
df_top_med_classes
# Out:
#                                Med_class  Quantity Sold
# 0            5-Alpha Reductase Inhibitor        1101549
# 1                        Alpha-2 Agonist         802378
# 2                          Alpha-Blocker        2625280
# 3                              Analgesic        1061008
# 4                             Antibiotic        1259910
# 5                         Anticonvulsant        2514863
# 6                             Antifungal        1819102
# 7                         Benzodiazepine        1705063
# 8                           Beta-Blocker        2062362
# 9                         Corticosteroid        1776749
# 10           High-Potency Corticosteroid        1509454
# 11                Inhaled Corticosteroid        1112097
# 12            Low-Potency Corticosteroid        1519123
# 13   Nonsteroidal Anti-Inflammatory Drug        4153538
# 14                      Opioid Analgesic        1514248
# 15    Phosphodiesterase Type 5 Inhibitor        2838613
# ...

# %%
df_top_med_classes = df_top_med_classes.sort_values(by='Quantity Sold')

# %%
plt.barh(df_top_med_classes['Med_class'],df_top_med_classes['Quantity Sold'])
plt.title(f'Top {top_number} Medication by Quantity Sold')
plt.xlabel('Quantity Sold')
plt.ylabel('Medication Class')
plt.show()

# %%
# !pip install wordcloud
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\envs\tf\lib\site-packages)

# %%
from wordcloud import WordCloud
# word cloud of medication classes
med_classes = df_ph['Med_class'].str.cat(sep='')
wordcloud  = WordCloud(width=800, height=400).generate(med_classes)
plt.figure(figsize=(14,7))
plt.imshow(wordcloud,interpolation='bilinear')
plt.show()

# %%
from wordcloud import WordCloud
# word cloud of medication classes
med_names = df_ph['Med_name'].str.cat(sep='')
wordcloud  = WordCloud(width=800, height=400).generate(med_names)
plt.figure(figsize=(14,7))
plt.imshow(wordcloud,interpolation='bilinear')
plt.show()

# %% [markdown]
# # Demand Forcast

# %%
# !pip install prophet
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\envs\tf\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\envs\tf\lib\site-packages)

# %%
from prophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
df_ph
# Out:
#          Date Sold                                     Med_name  \
# 0       2021-05-07              Clotrimazole Topical Cream (2%)
# 1       2021-08-09   Alprostadil Urethral Suppository (125 mcg)
# 2       2021-06-15            Methyltestosterone Tablet (10 mg)
# 3       2021-02-19                      Buspirone Tablet (5 mg)
# 4       2022-09-24  Hydrocodone/Acetaminophen Tablet (5/325 mg)
# ...            ...                                          ...
# 999995  2020-11-29   Alprostadil Urethral Suppository (125 mcg)
# 999996  2021-03-30                   Fenoprofen Tablet (600 mg)
# 999997  2020-04-17                      Doxazosin Tablet (1 mg)
# 999998  2021-12-08             Flumazenil Injection (0.1 mg/mL)
# 999999  2022-08-16                   Prednisolone Tablet (5 mg)
#
#                                       Med_class  Quantity Sold  Price
# 0                                    Antifungal             66   86.9
# ...

# %%
df_prophet = df_ph[df_ph['Med_class'].str.contains('Anxiolytic')][['Date Sold', 'Quantity Sold']]

# %%
df_prophet
# Out:
#          Date Sold  Quantity Sold
# 3       2021-02-19             89
# 122     2022-03-01             82
# 143     2020-08-11             17
# 327     2020-12-08             86
# 518     2019-03-31             70
# ...            ...            ...
# 999594  2019-08-11             42
# 999711  2020-05-16             71
# 999772  2019-09-02             63
# 999883  2019-09-09             38
# 999929  2023-03-25              4
#
# [10004 rows x 2 columns]

# %%
df_prophet = df_prophet.reset_index()
df_prophet
# Out:
#         index   Date Sold  Quantity Sold
# 0           3  2021-02-19             89
# 1         122  2022-03-01             82
# 2         143  2020-08-11             17
# 3         327  2020-12-08             86
# 4         518  2019-03-31             70
# ...       ...         ...            ...
# 9999   999594  2019-08-11             42
# 10000  999711  2020-05-16             71
# 10001  999772  2019-09-02             63
# 10002  999883  2019-09-09             38
# 10003  999929  2023-03-25              4
#
# [10004 rows x 3 columns]

# %%
df_prophet = df_prophet.rename(columns={'Date Sold':'ds','Quantity Sold':'y'})
df_prophet
# Out:
#         index          ds   y
# 0           3  2021-02-19  89
# 1         122  2022-03-01  82
# 2         143  2020-08-11  17
# 3         327  2020-12-08  86
# 4         518  2019-03-31  70
# ...       ...         ...  ..
# 9999   999594  2019-08-11  42
# 10000  999711  2020-05-16  71
# 10001  999772  2019-09-02  63
# 10002  999883  2019-09-09  38
# 10003  999929  2023-03-25   4
#
# [10004 rows x 3 columns]

# %%
type(df_prophet['ds'][0])
# Out:
# str

# %%
df_prophet['ds'] = pd.to_datetime(df_prophet['ds'])

# %%
type(df_prophet['ds'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
model = Prophet()

# %%
model.fit(df_prophet)
# Out:
# 19:52:29 - cmdstanpy - INFO - Chain [1] start processing
# 19:52:30 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=365)
forecast = model.predict(future)

# %%
fig = model.plot(forecast)
plt.show()

# %%
fig = model.plot_components(forecast)
plt.show()
